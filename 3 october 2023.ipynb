# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
x=np.array([1,2,3,4,5,6])
y= x**2
y2=x

# %%
plt.plot(x,y,"r-o",x,y2,"k--*")
plt.title("First plot")
plt.xlabel("The value of x ")
plt.ylabel("The value of y ")
plt.legend(["x","x^2"])
plt.grid(True) #|| plt.grid("on")
plt.gcf().set_size_inches(12,6)
plt.show()

# %%
fig, ax=plt.subplots(nrows=1,ncols=2,sharey=True)
ax[0].plot(x,y)
ax[1].plot(x,y2)
plt.gcf().set_size_inches(12,8)
fig

# %%
plt.rcParams.keys
# Out:
# <bound method RcParams.keys of RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.mencoder_args': [],
#           'animation.mencoder_path': 'mencoder',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.formatter.limits': [-7, 7],
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
plt.bar(range(6),y2)
plt.show()

# %% [markdown]
# ### Assignment

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')
print(df)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
data=np.random.randint(1,100,100)
plt.hist(data,bins=50,width=0.5)
plt.show()

# %%
data
# Out:
# array([71,  1, 35, 70, 49, 68, 25, 79, 65, 31, 86, 98, 73, 41, 29, 81, 66,
#        80, 14, 42, 57, 59, 23, 63, 96, 79, 43, 32, 15, 44, 17, 69, 61, 32,
#        71, 25, 32, 14, 72, 30, 71, 73, 45, 50, 15, 32, 38, 49, 59, 12, 26,
#        80, 94,  5, 70, 87, 10, 90, 82,  9, 50, 59, 44, 86, 26, 96, 51,  7,
#        90, 72, 73, 82, 11, 24, 43, 58, 43, 51, 61, 75, 63,  3,  6, 71, 23,
#        19, 87, 73, 97, 10, 73, 44, 18, 10,  4, 43, 27, 38,  5, 32])

# %%
plt.rcParams["hist.bins"]=20

# %%
plt.scatter(x,y,s=400,c="b")
plt.show()

# %%
plt.boxplot(data,notch=True,whis=False)
plt.show()
